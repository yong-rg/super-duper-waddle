# %%
import pandas as pd
import openpyxl
import duckdb
import re

# %%
amz = 'https://docs.google.com/spreadsheets/d/1pP8jJDYPS1nHjHHDM1IycjtdFLLJIA8kRQ5AaC32Su0'
google = 'https://docs.google.com/spreadsheets/d/1oADSDDLjFmVs5tkc6KxJQW5B0VRg1qxaSqtQSV6EemA'


urls = [amz, google]

# %%
duckdb.sql(f"""DROP TABLE IF EXISTS amz""")
duckdb.sql(f"""DROP TABLE IF EXISTS google""")

# %%
print(amz)
u = f'{amz}/export?format=xlsx'

xl = pd.ExcelFile(u)

sheet_names = xl.sheet_names
num_sheets = len(sheet_names)
print(sheet_names)
print(num_sheets)

df = pd.read_excel(xl,2)

df = pd.DataFrame(df)

display(df)

duckdb.sql(f"""CREATE TABLE IF NOT EXISTS amz AS SELECT * FROM df""")
# Out:
# https://docs.google.com/spreadsheets/d/1pP8jJDYPS1nHjHHDM1IycjtdFLLJIA8kRQ5AaC32Su0
# ['campaign', 'ad group', 'asin', 'campaign_src', 'ad group_src', 'lens spray_src', 'cleaning kit_src', 'lens cleaner_src', 'lens wipes_src']
# 9
#                Campaign                                            Product  \
# 0   Lens Spray | Search  ZEISS Pre-Moistened Lens Cleaning Wipes, 600 C...
# 1   Lens Spray | Search  ZEISS Jumbo Microfiber Cleaning Cloth for Coat...
# 2   Lens Spray | Search  ZEISS Pre-Moistened Lens Cleaning Wipes, 200 C...
# 3   Lens Spray | Search  ZEISS Lens Care Pack - 2-8 Ounce Bottles of Le...
# 4   Lens Spray | Search          ZEISS Lens Cleaning Spray 2oz - Pack of 2
# ..                  ...                                                ...
# 90  Lens Wipes | Search  Zeiss Microfiber Lens Cleaning Cloth (Pack of ...
# 91  Lens Wipes | Search  Zeiss Microfiber Lens Cleaning Cloth (Pack of ...
# 92  Lens Wipes | Search  Zeiss Microfiber Lens Cleaning Cloth (Pack of ...
# 93  Lens Wipes | Search  ZEISS Lens Cleaning Accessory Tin Box Containe...
# 94  Lens Wipes | Search  Zeiss Microfiber Lens Cleaning Cloth (Pack of ...
#
#           ASIN  DPV  ATC  Purchases   Sales
# 0   B003O5FCZ6    6    1          1   31.98
# 1   B008PNNY02    7    1          1    5.98
# 2   B00GL64QG6    2    0          0    0.00
# 3   B00GPVQVCO  486   61         38  482.51
# 4   B00JFD6KAW  541   55         30  258.87
# ..         ...  ...  ...        ...     ...
# 90  B0CW7FMZSY    2    1          0    0.00
# 91  B0CW7FMZSY    2    1          0    0.00
# 92  B0CW7FMZSY    2    1          0    0.00
# 93  B0CKTPV86T   26    5          2   15.37
# 94  B0CW7FMZSY    2    1          0    0.00
#
# [95 rows x 7 columns]

# %%
print(google)
u = f'{google}/export?format=xlsx'

xl = pd.ExcelFile(u)

sheet_names = xl.sheet_names
num_sheets = len(sheet_names)
print(sheet_names)
print(num_sheets)

df = pd.read_excel(xl,3)

df = pd.DataFrame(df)

links = df.URL
asin_url = []

for l in links:
    asin = re.findall(r'(?<=\/)[A-Za-z0-9]{10}', l)
    asin_url.append(asin[0])

print(asin_url)

df['ASIN'] = asin_url

display(df)

duckdb.sql(f"""CREATE TABLE IF NOT EXISTS google AS SELECT * FROM df""")
# Out:
# https://docs.google.com/spreadsheets/d/1oADSDDLjFmVs5tkc6KxJQW5B0VRg1qxaSqtQSV6EemA
# ['Google', 'MTD Src', 'L30 Src', 'Ad Src']
# 4
# ['B00GPVQVCO', 'B00GPVQVCO', 'B0030E4UIQ', 'B00GPVQVCO', 'B0030E4UIQ', 'B00GPVQVCO', 'B00GPVQVCO', 'B00JFD6KAW', 'B00GPVQVCO', 'B00JFD6KAW', 'B0030E4UIQ', 'B078WGKW65', 'B0030E4UIQ', 'B078WGKW65', 'B0030E4UIQ', 'B078WGKW65']
#            Ad ID  Status               Campaign              Ad Group  \
# 0   707535460988    True  Cleaning Kit | Search                Cloths
# 1   707449931704    True  Cleaning Kit | Search    Lens Kit | Generic
# 2   707456264812    True  Lens Cleaner | Search          LC | Generic
# 3   707587121425    True  Lens Cleaner | Search          LC | Generic
# 4   713521850389    True  Lens Cleaner | Search              LC | AMZ
# 5   713605442306    True  Lens Cleaner | Search              LC | AMZ
# 6   707425605348    True    Lens Spray | Search         Glasses Spray
# 7   707587121422    True    Lens Spray | Search         Glasses Spray
# 8   707532343400    True    Lens Spray | Search  Lens Spray | Generic
# 9   707587121419    True    Lens Spray | Search  Lens Spray | Generic
# 10  707421662364    True    Lens Wipes | Search          LW | Generic
# 11  707587121428    True    Lens Wipes | Search          LW | Generic
# 12  713947815973    True    Lens Wipes | Search              LW | AMZ
# 13  713947815976    True    Lens Wipes | Search              LW | AMZ
# 14  707444677393    True    Lens Wipes | Search    LW | Glasses Wipes
# 15  707587121431    True    Lens Wipes | Search    LW | Glasses Wipes
#
#                                                   URL     Cost  Impressions  \
# 0   https://www.amazon.com/Zeiss-Lens-Care-Pack-Mi...    17.48           88
# 1   https://www.amazon.com/Zeiss-Lens-Care-Pack-Mi...  1404.38         6227
# 2   https://www.amazon.com/Zeiss-Pre-Moistened-Len...  1192.74         9012
# 3   https://www.amazon.com/Zeiss-Lens-Care-Pack-Mi...  1199.16         8375
# 4   https://www.amazon.com/dp/B0030E4UIQ?maas=maas...    28.03           74
# 5   https://www.amazon.com/Zeiss-Lens-Care-Pack-Mi...    18.73           62
# 6   https://www.amazon.com/Zeiss-Lens-Care-Pack-Mi...   593.23         3802
# 7   https://www.amazon.com/Carl-Zeiss-Lens-Cleanin...   741.01         4207
# 8   https://www.amazon.com/Zeiss-Lens-Care-Pack-Mi...     1.60            7
# 9   https://www.amazon.com/Carl-Zeiss-Lens-Cleanin...     3.00            7
# 10  https://www.amazon.com/Zeiss-Pre-Moistened-Len...   493.04         3319
# 11  https://www.amazon.com/Zeiss-Moistened-Cleanin...   401.50         2323
# 12  https://www.amazon.com/dp/B0030E4UIQ?maas=maas...    37.53          107
# 13  https://www.amazon.com/dp/B078WGKW65?maas=maas...    35.88           99
# 14  https://www.amazon.com/Zeiss-Pre-Moistened-Len...  1228.91         7224
# 15  https://www.amazon.com/Zeiss-Moistened-Cleanin...  1106.87         6314
#
#     Clicks      CTR       CPC        ASIN
# 0       10  0.11364  1.748000  B00GPVQVCO
# 1      712  0.11434  1.972444  B00GPVQVCO
# 2      877  0.09731  1.360023  B0030E4UIQ
# 3      879  0.10496  1.364232  B00GPVQVCO
# 4       22  0.29730  1.274091  B0030E4UIQ
# 5       17  0.27419  1.101765  B00GPVQVCO
# 6      408  0.10731  1.453995  B00GPVQVCO
# 7      513  0.12194  1.444464  B00JFD6KAW
# 8        1  0.14286  1.600000  B00GPVQVCO
# 9        2  0.28571  1.500000  B00JFD6KAW
# 10     338  0.10184  1.458698  B0030E4UIQ
# 11     264  0.11365  1.520833  B078WGKW65
# 12      30  0.28037  1.251000  B0030E4UIQ
# 13      30  0.30303  1.196000  B078WGKW65
# 14     790  0.10936  1.555582  B0030E4UIQ
# 15     706  0.11182  1.567805  B078WGKW65

# %%
duckdb.execute("""
                SELECT Campaign, SUM(COST) as Cost
                FROM google
                GROUP BY Campaign 
                ORDER BY Campaign
""").df()
# Out:
#                 Campaign     Cost
# 0  Cleaning Kit | Search  1421.86
# 1  Lens Cleaner | Search  2438.66
# 2    Lens Spray | Search  1338.84
# 3    Lens Wipes | Search  3303.73

# %%
duckdb.execute("""
               SELECT Campaign, sum(Sales), sum(DPV), sum(ATC)
               FROM amz
               GROUP BY Campaign
""").df()
# Out:
#                 Campaign  sum(Sales)  sum(DPV)  sum(ATC)
# 0    Lens Spray | Search      849.53    1156.0     134.0
# 1  Cleaning Kit | Search      751.28    1006.0      92.0
# 2  Lens Cleaner | Search     1673.38    2098.0     238.0
# 3    Lens Wipes | Search     2752.70    2801.0     393.0

# %%
# ASIN
duckdb.execute("""
                SELECT DISTINCT
                    g.ASIN,
                    g.Campaign,
                    g.Cost,
                    g.Impressions,
                    g.Clicks,
                    g.CPC,
                    a.DPV,
                    a.ATC,
                    a.Purchases,
                    a.Sales
                FROM google as g
                LEFT JOIN amz a
                ON g.ASIN = a.ASIN
                ORDER BY g.Campaign ASC
""").df()

# Ad Group

# Aggregate
# Out:
#           ASIN               Campaign     Cost  Impressions  Clicks       CPC  \
# 0   B00GPVQVCO  Cleaning Kit | Search    17.48           88      10  1.748000
# 1   B00GPVQVCO  Cleaning Kit | Search    17.48           88      10  1.748000
# 2   B00GPVQVCO  Cleaning Kit | Search  1404.38         6227     712  1.972444
# 3   B00GPVQVCO  Cleaning Kit | Search  1404.38         6227     712  1.972444
# 4   B00GPVQVCO  Cleaning Kit | Search    17.48           88      10  1.748000
# 5   B00GPVQVCO  Cleaning Kit | Search    17.48           88      10  1.748000
# 6   B00GPVQVCO  Cleaning Kit | Search  1404.38         6227     712  1.972444
# 7   B00GPVQVCO  Cleaning Kit | Search  1404.38         6227     712  1.972444
# 8   B00GPVQVCO  Lens Cleaner | Search    18.73           62      17  1.101765
# 9   B00GPVQVCO  Lens Cleaner | Search  1199.16         8375     879  1.364232
# 10  B0030E4UIQ  Lens Cleaner | Search    28.03           74      22  1.274091
# 11  B00GPVQVCO  Lens Cleaner | Search  1199.16         8375     879  1.364232
# 12  B00GPVQVCO  Lens Cleaner | Search  1199.16         8375     879  1.364232
# 13  B00GPVQVCO  Lens Cleaner | Search    18.73           62      17  1.101765
# 14  B0030E4UIQ  Lens Cleaner | Search  1192.74         9012     877  1.360023
# 15  B00GPVQVCO  Lens Cleaner | Search    18.73           62      17  1.101765
# 16  B0030E4UIQ  Lens Cleaner | Search  1192.74         9012     877  1.360023
# 17  B00GPVQVCO  Lens Cleaner | Search  1199.16         8375     879  1.364232
# 18  B0030E4UIQ  Lens Cleaner | Search  1192.74         9012     877  1.360023
# 19  B00GPVQVCO  Lens Cleaner | Search    18.73           62      17  1.101765
# 20  B0030E4UIQ  Lens Cleaner | Search    28.03           74      22  1.274091
# 21  B0030E4UIQ  Lens Cleaner | Search    28.03           74      22  1.274091
# 22  B00JFD6KAW    Lens Spray | Search   741.01         4207     513  1.444464
# 23  B00JFD6KAW    Lens Spray | Search   741.01         4207     513  1.444464
# 24  B00GPVQVCO    Lens Spray | Search   593.23         3802     408  1.453995
# 25  B00GPVQVCO    Lens Spray | Search     1.60            7       1  1.600000
# 26  B00JFD6KAW    Lens Spray | Search     3.00            7       2  1.500000
# 27  B00GPVQVCO    Lens Spray | Search   593.23         3802     408  1.453995
# 28  B00JFD6KAW    Lens Spray | Search     3.00            7       2  1.500000
# 29  B00GPVQVCO    Lens Spray | Search     1.60            7       1  1.600000
# 30  B00JFD6KAW    Lens Spray | Search   741.01         4207     513  1.444464
# 31  B00GPVQVCO    Lens Spray | Search     1.60            7       1  1.600000
# 32  B00JFD6KAW    Lens Spray | Search     3.00            7       2  1.500000
# 33  B00JFD6KAW    Lens Spray | Search     3.00            7       2  1.500000
# 34  B00GPVQVCO    Lens Spray | Search   593.23         3802     408  1.453995
# 35  B00GPVQVCO    Lens Spray | Search     1.60            7       1  1.600000
# 36  B00GPVQVCO    Lens Spray | Search   593.23         3802     408  1.453995
# 37  B00JFD6KAW    Lens Spray | Search   741.01         4207     513  1.444464
# 38  B078WGKW65    Lens Wipes | Search  1106.87         6314     706  1.567805
# 39  B0030E4UIQ    Lens Wipes | Search  1228.91         7224     790  1.555582
# 40  B078WGKW65    Lens Wipes | Search   401.50         2323     264  1.520833
# 41  B0030E4UIQ    Lens Wipes | Search    37.53          107      30  1.251000
# 42  B078WGKW65    Lens Wipes | Search   401.50         2323     264  1.520833
# 43  B078WGKW65    Lens Wipes | Search  1106.87         6314     706  1.567805
# 44  B078WGKW65    Lens Wipes | Search  1106.87         6314     706  1.567805
# 45  B078WGKW65    Lens Wipes | Search    35.88           99      30  1.196000
# 46  B0030E4UIQ    Lens Wipes | Search   493.04         3319     338  1.458698
# 47  B0030E4UIQ    Lens Wipes | Search  1228.91         7224     790  1.555582
# 48  B078WGKW65    Lens Wipes | Search  1106.87         6314     706  1.567805
# 49  B078WGKW65    Lens Wipes | Search    35.88           99      30  1.196000
# 50  B0030E4UIQ    Lens Wipes | Search    37.53          107      30  1.251000
# 51  B078WGKW65    Lens Wipes | Search    35.88           99      30  1.196000
# 52  B0030E4UIQ    Lens Wipes | Search   493.04         3319     338  1.458698
# 53  B0030E4UIQ    Lens Wipes | Search  1228.91         7224     790  1.555582
# 54  B078WGKW65    Lens Wipes | Search    35.88           99      30  1.196000
# 55  B078WGKW65    Lens Wipes | Search   401.50         2323     264  1.520833
# 56  B0030E4UIQ    Lens Wipes | Search    37.53          107      30  1.251000
# 57  B078WGKW65    Lens Wipes | Search   401.50         2323     264  1.520833
# 58  B0030E4UIQ    Lens Wipes | Search   493.04         3319     338  1.458698
#
#      DPV  ATC  Purchases    Sales
# 0    937   74         44   550.38
# 1    750   33         21   262.93
# 2    937   74         44   550.38
# 3    750   33         21   262.93
# 4     33    5          4    49.07
# 5    486   61         38   482.51
# 6    486   61         38   482.51
# 7     33    5          4    49.07
# 8    937   74         44   550.38
# 9    486   61         38   482.51
# 10   912   64         42   447.30
# 11   750   33         21   262.93
# 12   937   74         44   550.38
# 13   486   61         38   482.51
# 14    59   17         10   149.10
# 15    33    5          4    49.07
# 16  1307  161        113  1269.43
# 17    33    5          4    49.07
# 18   912   64         42   447.30
# 19   750   33         21   262.93
# 20  1307  161        113  1269.43
# 21    59   17         10   149.10
# 22    56   12          6    49.39
# 23    66   30         20   182.92
# 24    33    5          4    49.07
# 25   937   74         44   550.38
# 26   541   55         30   258.87
# 27   750   33         21   262.93
# 28     8    2          2    17.69
# 29   486   61         38   482.51
# 30   541   55         30   258.87
# 31   750   33         21   262.93
# 32    56   12          6    49.39
# 33    66   30         20   182.92
# 34   486   61         38   482.51
# 35    33    5          4    49.07
# 36   937   74         44   550.38
# 37     8    2          2    17.69
# 38    17   10          9    46.20
# 39   912   64         42   447.30
# 40    17   10          9    46.20
# 41  1307  161        113  1269.43
# 42  1048  144        102   502.98
# 43    32    8          7    36.96
# 44    53   37         25   119.82
# 45  1048  144        102   502.98
# 46   912   64         42   447.30
# 47  1307  161        113  1269.43
# 48  1048  144        102   502.98
# 49    17   10          9    46.20
# 50    59   17         10   149.10
# 51    32    8          7    36.96
# 52    59   17         10   149.10
# 53    59   17         10   149.10
# 54    53   37         25   119.82
# 55    32    8          7    36.96
# 56   912   64         42   447.30
# 57    53   37         25   119.82
# 58  1307  161        113  1269.43

# %%
# Campaign
duckdb.execute("""
                SELECT DISTINCT
                    g.Campaign,
                    g.Cost as Cost,
                    g.Impressions,
                    g.Clicks,
                    g.CPC,
                    a.DPV,
                    a.ATC,
                    a.Purchases as Purchases,
                    a.Sales as Sales,
                    a.Sales / g.Cost as ROAS
                FROM google as g
                LEFT JOIN amz a
                ON g.Campaign = a.Campaign
""").df()
# Out:
#                   Campaign     Cost  Impressions  Clicks       CPC   DPV  ATC  \
# 0      Lens Spray | Search     3.00            7       2  1.500000   541   55
# 1      Lens Spray | Search     3.00            7       2  1.500000     8    0
# 2    Cleaning Kit | Search  1404.38         6227     712  1.972444     1    0
# 3    Cleaning Kit | Search  1404.38         6227     712  1.972444    59   17
# 4    Cleaning Kit | Search  1404.38         6227     712  1.972444    56   12
# ..                     ...      ...          ...     ...       ...   ...  ...
# 313    Lens Wipes | Search   401.50         2323     264  1.520833     8    2
# 314    Lens Wipes | Search   401.50         2323     264  1.520833    81   32
# 315    Lens Wipes | Search   401.50         2323     264  1.520833    30    7
# 316    Lens Wipes | Search   493.04         3319     338  1.458698  1307  161
# 317    Lens Wipes | Search   493.04         3319     338  1.458698     4    0
#
#      Purchases    Sales       ROAS
# 0           30   258.87  86.290000
# 1            0     0.00   0.000000
# 2            0     0.00   0.000000
# 3           10   149.10   0.106168
# 4            6    49.39   0.035169
# ..         ...      ...        ...
# 313          2    17.69   0.044060
# 314         21   475.25   1.183686
# 315          5   105.08   0.261719
# 316        113  1269.43   2.574700
# 317          0     0.00   0.000000
#
# [318 rows x 10 columns]
